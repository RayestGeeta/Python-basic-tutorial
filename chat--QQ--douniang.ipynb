# %%
from qqbot import _bot as bot
bot.Login(['-q', '623889633'])
# Out:
# [2018-03-02 13:37:16] [INFO] QQBot-v2.3.10
# [2018-03-02 13:37:16] [INFO] Python 3.6.3
# [2018-03-02 13:37:16] [INFO] 工作目录：/home/shihao-z/.qqbot-tmp
# [2018-03-02 13:37:16] [INFO] 配置文件：/home/shihao-z/.qqbot-tmp/v2.3.conf
# [2018-03-02 13:37:16] [INFO] 用户名：无
# [2018-03-02 13:37:16] [INFO] 登录方式：自动（qq=623889633）
# [2018-03-02 13:37:16] [INFO] 命令行服务器端口号：8188
# [2018-03-02 13:37:16] [INFO] 二维码服务器 ip ：无
# [2018-03-02 13:37:16] [INFO] 二维码服务器端口号：无
# [2018-03-02 13:37:16] [INFO] 用于接收二维码的邮箱账号：无
# [2018-03-02 13:37:16] [INFO] 邮箱服务授权码：无
# [2018-03-02 13:37:16] [INFO] 以文本模式显示二维码：否
# [2018-03-02 13:37:16] [INFO] 调试模式：关闭
# [2018-03-02 13:37:16] [INFO] 掉线后自动重启：否
# [2018-03-02 13:37:16] [INFO] 后台模式（daemon 模式）：否
# [2018-03-02 13:37:16] [INFO] 启动方式：快速启动（登录成功后立即启动）
# [2018-03-02 13:37:16] [INFO] 插件目录1：/home/shihao-z/.qqbot-tmp/plugins
# [2018-03-02 13:37:16] [INFO] 启动时需要加载的插件：['qqbot.plugins.sampleslots', 'qqbot.plugins.schedrestart']
# ...

# %%
g = bot.List('group', '1720牛逼轰轰带闪电')[0]

# %%
bot.List(g,'周婷')
# Out:
# [成员“周婷”]

# %%
bot.List('group')
# Out:
# [群“大工唐中母校行”,
#  群“校团委2018寒假母校行”,
#  群“2018运载母校行队长群”,
#  群“大工二中人”,
#  群“王者二班”,
#  群“螺丝2017”,
#  群“v5二中软件人”,
#  群“1710”,
#  群“唐河县第一高级群组”,
#  群“one seven one zero”,
#  群“403小窝”,
#  群“冬令营同学”,
#  群“螺丝工作室游戏组”,
#  群“大工软院河南老乡群”,
#  群“大連理工河南同乡群”,
#  群“python学习”,
#  群“十班少年不再年少”,
#  群“大工软院打印帮忙群”,
#  群“软院学长学姐帮帮忙！”,
#  群“1720牛逼轰轰带闪电”,
#  群“111111710通知群”,
#  群“螺丝ds/dl组”,
#  群“VR兴趣小组”,
#  群“2017青年志愿者协会”,
#  群“软院拼车群”,
#  群“Python免费学习2群”,
#  群“403工资事务群”,
#  群“403工作专用”,
#  群“i春秋-楚”,
#  群“2017级公益时长统计群”,
#  群“DUT程序员交流群”,
#  群“2017朗润天文社”,
#  群“数模组2017”,
#  群“403多媒体检修”,
#  群“唐中骐骥班”,
#  群“开发区校区二手市场”,
#  群“2018运载寒假母校行群”,
#  群“209宿舍”,
#  群“2019春招备战大群”,
#  群“软件2017级二级队”,
#  群“CIPPUS-SSS-Android”,
#  群“周末多媒体检修”,
#  群“软院第十三届辩论协会”,
#  群“DC学院大数据交流群”,
#  群“2017开发区校区acm新生”,
#  群“17新生”,
#  群“1710冠军梦之队🏀”,
#  群“我们导师是姜老师”,
#  群“2018寒假实践1群”,
#  群“勤工俭学”,
#  群“17年朗润天文社核心”,
#  群“活力四舍😏😃😄🙃”,
#  群“螺丝开发运维组2017”,
#  群“2017年爱心包裹志愿者”,
#  群“洋洋群”]

# %%
bot.List('buddy')
# Out:
# [好友“ 邹   ”,
#  好友“+se钕q:66630640有惊喜”,
#  好友“刘雨晴”,
#  好友“橘橘子”,
#  好友“小陌”,
#  好友“厦梦倩”,
#  好友“sdsfd”,
#  好友“丧失小冲冲”,
#  好友“ttyyuu”,
#  好友“苟展硕”,
#  好友“2.10赵宝星”,
#  好友“阿泽☘”,
#  好友“朵琳。”,
#  好友“babyQ”,
#  好友“冰冰姐。”,
#  好友“@摘录墙”,
#  好友“林媛媛Set”,
#  好友“大学生辅导君”,
#  好友“宇涵”,
#  好友“蓝宜”,
#  好友“青柠”,
#  好友“乔博”,
#  好友“孙之桓”,
#  好友“|夏颜”,
#  好友“吴琴”,
#  好友“王中立”,
#  好友“运船17赵旭崇”,
#  好友“17 江苏 软件”,
#  好友“鹿益铭”,
#  好友“空人空心空世界”,
#  好友“问路处”,
#  好友“1709-吴清宇”,
#  好友“游戏-屠智文”,
#  好友“15-刘潇”,
#  好友“17 秦 杨”,
#  好友“韩中璇”,
#  好友“贺亚奇”,
#  好友“✨不见伊”,
#  好友“历害哥”,
#  好友“宋小萌撒”,
#  好友“新权”,
#  好友“闪烁.”,
#  好友“R”,
#  好友“17－软件工程－迎”,
#  好友“曲”,
#  好友“1715-王涵”,
#  好友“罗小鸣”,
#  好友“叶家铭”,
#  好友“~~尋夢の憂傷、、”,
#  好友“ds/dl-次元政”,
#  好友“邓大新”,
#  好友“孙启东”,
#  好友“邓达开”,
#  好友“All right”,
#  好友“16-王诗玮”,
#  好友“靖雷婷”,
#  好友“b学习部-叶淞任”,
#  好友“逯其政”,
#  好友“樊宇”,
#  好友“王者璇”,
#  好友“邸潇-软件-17”,
#  好友“d-汪萌萌”,
#  好友“软糖💫”,
#  好友“孙语晨是语晨这两”,
#  好友“刘张澳”,
#  好友“哆啦A梦@”,
#  好友“e-韩昱炜”,
#  好友“单单”,
#  好友“潘畅”,
#  好友“新宇”,
#  好友“李晨”,
#  好友“王子栋”,
#  好友“张凯雯”,
#  好友“陈鹏宇”,
#  好友“王熠”,
# ...

# %%
bot.Update('buddy')
# Out:
# [2018-03-01 16:50:36] [INFO] 正在获取 好友列表 ...
# [2018-03-01 16:50:36] [WARNING] 因腾讯关闭了 qun.qq.com 的接口，无法获取到好友的真实 QQ 号码！
# [2018-03-01 16:50:36] [INFO] 已获取并更新 好友列表
# True

# %%
g = bot.List('buddy', '何承栋')[0]

# %%
bot.SendTo(g, '猜猜我是谁？尔莎子')
# Out:
# [2018-03-02 13:39:11] [INFO] 向 好友“何承栋” 发消息成功：猜猜我是谁？尔莎子
# '向 好友“何承栋” 发消息成功'

# %%
g = bot.List('group', '1720牛逼轰轰带闪电')[0]
member = bot.List(g, '刘张澳')
print(g,member)
# Out:
# 群“1720牛逼轰轰带闪电” [成员“刘张澳”]

# %%
bot.GroupShut(g, member, 120)
# Out:
# ['错误：群或某个成员的 qq 属性是 "#NULL"']
